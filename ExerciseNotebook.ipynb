# %% [markdown]
# # Exercise Notebook

# %%
type(11), type("hello"), type(22.3)
# Out:
# (int, str, float)

# %%
type(0)
# Out:
# int

# %%
type(-345)
# Out:
# int

# %%
float(2)
# Out:
# 2.0

# %%
int(2.34)
# Out:
# 2

# %%
type(True)
# Out:
# bool

# %%
int(False)
# Out:
# 0

# %%
bool(1)
# Out:
# True

# %%
25/6
# Out:
# 4.166666666666667

# %%
25//6
# Out:
# 4

# %%
12/5
# Out:
# 2.4

# %%
12//5
# Out:
# 2

# %%
12/7
# Out:
# 1.7142857142857142

# %%
12//7
# Out:
# 1

# %%
11//2
# Out:
# 5

# %%
var1=5
var2=2

# %%
var1+var2
# Out:
# 7

# %%
x=20+30+50
y=x/2

# %%
y
# Out:
# 50.0

# %%
x=x-3
y=x/2

# %%
y
# Out:
# 45.5

# %%
import sys
print(sys.version)
# Out:
# 3.8.8 (default, Apr 13 2021, 12:59:45)
# [Clang 10.0.0 ]

# %%
sys.float_info #learn more about the specifics of floats for your runtime environment
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
bool(3)
# Out:
# True

# %%
bool(10000)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(-1)
# Out:
# True

# %%
bool(1.6)
# Out:
# True

# %%
bool(0.3)
# Out:
# True

# %%
11//2
# Out:
# 5

# %%
my_name="Sadia Schuelke"

# %%
my_name
# Out:
# 'Sadia Schuelke'

# %%
first_name=my_name[0:5]
first_name
# Out:
# 'Sadia'

# %%
my_name[::2] #gives every second character
# Out:
# 'SdaShek'

# %%
my_name[0:5:2] # every second character up to index 4
# Out:
# 'Sda'

# %%
len("Sadia")
# Out:
# 5

# %%
len(my_name)
# Out:
# 14

# %%
unicorn1="Eini"
statement=unicorn1+" is the best!" #combining strings
statement
# Out:
# 'Eini is the best!'

# %%
3*unicorn1
# Out:
# 'EiniEiniEini'

# %%
3*'Eini'
# Out:
# 'EiniEiniEini'

# %%
print('Eini is \n the best')
# Out:
# Eini is
#  the best

# %%
print('Eini \t is \n the best \\ yay')
# Out:
# Eini 	 is
#  the best \ yay

# %%
print(r'Eini is \n the best') #r suppresses escape sequence
# Out:
# Eini is \n the best

# %%
unicorn1.upper()
# Out:
# 'EINI'

# %%
unicorn1.replace('Eini','Luna')
# Out:
# 'Luna'

# %%
unicorn1.find('Ei')
# Out:
# 0

# %%
print(unicorn1)
# Out:
# Eini

# %%
print(unicorn1, "is the best")
# Out:
# Eini is the best

# %%
type(int(12.3))
# Out:
# int

# %%
tuple1=('Eini','Luna','Bob', 3,5,68,4.5,7.8)
tuple2=(1,5,3,8,10)
tuple3=(1,4.3,5.2,2.8,10)

# %%
sorted(tuple2) #gives sorted list
# Out:
# [1, 3, 5, 8, 10]

# %%
sorted(tuple3)
# Out:
# [1, 2.8, 4.3, 5.2, 10]

# %%
tuple_nesting=('Eini',('Luna','Coco'), 3)

# %%
tuple_nesting[1]
# Out:
# ('Luna', 'Coco')

# %%
tuple_nesting[1][0] #finding value ins subtuple during nesting
# Out:
# 'Luna'

# %%
"Eini loves you".split()
# Out:
# ['Eini', 'loves', 'you']

# %%
"A,B,C,D".split()
# Out:
# ['A,B,C,D']

# %%
"A B C D".split()
# Out:
# ['A', 'B', 'C', 'D']

# %%
example1="A,B,C,D".split('A') #splits at A
example2="A,B,C,D".split(',')
example1
# Out:
# ['', ',B,C,D']

# %%
example2
# Out:
# ['A', 'B', 'C', 'D']

# %%
"Eini loves you".split('l')
# Out:
# ['Eini ', 'oves you']

# %%
list1=['hello',1,2.3]

# %%
dictionary1={'Eini':3,'Luna':2} #dictionary, curly brackets

# %%
dictionary1['Luna']
# Out:
# 2

# %%
dictionary1['Bob']=10 #add value to dictionary

# %%
dictionary1
# Out:
# {'Eini': 3, 'Luna': 2, 'Bob': 10}

# %%
'Eini' in dictionary1
# Out:
# True

# %%
dictionary1.keys()
# Out:
# dict_keys(['Eini', 'Luna', 'Bob'])

# %%
dictionary1.values()
# Out:
# dict_values([3, 2, 10])

# %%
list=dictionary1.values()

# %%
list
# Out:
# dict_values([3, 2, 10])

# %%
set1={'Eini','Luna','Bob'}  #duplicates thrown out

# %%
set1
# Out:
# {'Bob', 'Eini', 'Luna'}

# %%
set(list1)
# Out:
# {1, 2.3, 'hello'}

# %%
set(list)
# Out:
# {2, 3, 10}

# %%
set1={'Eini','Luna','Bob'} 
set2={'Eini','Coco','Fred'}

# %%
set1 & set2 #intersection
# Out:
# {'Eini'}

# %%
set3=set1 & set2

# %%
set3
# Out:
# {'Eini'}

# %%
set3.issubset(set1)
# Out:
# True

# %%
set1.issuperset(set3)
# Out:
# True

# %%
A=((1),[2,3],[4])

# %%
A[2][0]
# Out:
# 4

# %%
len(("disco",10))
# Out:
# 2

# %%
 'A' in {'A','B'}
# Out:
# True

# %%
age=3

if age>18:
    print("you shall enter")
else:
    print("move on")
# Out:
# move on

# %%
not(False)
# Out:
# True

# %%
not(True)
# Out:
# False

# %%
range(3)
# Out:
# range(0, 3)

# %%
range(10,15)
# Out:
# range(10, 15)

# %%
for x in ['A','B','C']:

  print(x+'A')
# Out:
# AA
# BA
# CA

# %%
for i,x in enumerate(['A','B','C']):
    print(i,x)
# Out:
# 0 A
# 1 B
# 2 C

# %%
Genres = ['rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']
for x in Genres: # could be Genre or x or whatever, gives out list anyway
    print(x)
# Out:
# rock
# R&B
# Soundtrack
# R&B
# soul
# pop

# %%
import math
x = 5
math.cos(x)
# Out:
# 0.2836621854632263

# %%
math.sin(math.pi)
# Out:
# 1.2246467991473532e-16

# %%
math.sin(1)
# Out:
# 0.8414709848078965

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
def adding(a):   # building your own function
    b=a+1
    return b

# %%
adding(3)
# Out:
# 4

# %%
def mult(a,b):
    c=a*b
    return c

# %%
mult(4,5)
# Out:
# 20

# %%
def Print(A):
    for a in A:
        print(a+'1')
        
Print(['a','b','c'])
# Out:
# a1
# b1
# c1

# %%
def con(a, b):
    return(a + b)

# %%
con(3,4)
# Out:
# 7

# %%
con("Hello"," Eini")
# Out:
# 'Hello Eini'

# %%
def type_of_album(artist, album, year_released):
    
    print(artist, album, year_released)
    if year_released > 1980:
        return "Modern"  #can use return more than once in loops within functions
    else:
        return "Oldie"
    
x = type_of_album("Michael Jackson", "Thriller", 1980)
print(x)
# Out:
# Michael Jackson Thriller 1980
# Oldie

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a")) # input function
    a = a/b
    print("Success a=",a)
except:
    print("There was an error")
# Out:
# Please enter a number to divide a 0
# There was an error

# %%
list3=[23,3,6.7,5,1]
list3
# Out:
# [23, 3, 6.7, 5, 1]

# %%
list3.reverse() #using and calling methods
list3
# Out:
# [1, 5, 6.7, 3, 23]

# %%
list3.sort()
list3
# Out:
# [1, 3, 5, 6.7, 23]

# %%
a=1

def do(x):
    a=100
    return(x+a)

print(do(1))
# Out:
# 101

# %%
def add(a,b):
    return a+b

# %%
add(2,3)
# Out:
# 5
